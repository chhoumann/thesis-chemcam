# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import mlflow
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from lib import full_flow_dataloader

from lib.norms import Norm1Scaler, Norm3Scaler
from lib.reproduction import major_oxides

train_processed, test_processed = full_flow_dataloader.load_full_flow_data()

# %%
from sklearn.model_selection import train_test_split
from lib.utils import custom_train_test_split

train_cols = train_processed.columns
test_cols = test_processed.columns
norm = 3

scaler = Norm1Scaler() if norm == 1 else Norm3Scaler()

train = scaler.fit_transform(train_processed)
test = scaler.fit_transform(test_processed)

# turn back into dataframe
train = pd.DataFrame(train, columns=train_cols)
test = pd.DataFrame(test, columns=test_cols)

drop_cols = major_oxides + ["ID", "Sample Name"]

## - VALIDATION -
# split_train, split_val = custom_train_test_split(train, "Sample Name", test_size=0.2, random_state=42)

# X_train = split_train.drop(columns=drop_cols)
# y_train = split_train[major_oxides]
# X_val = split_val.drop(columns=drop_cols)
# y_val = split_val[major_oxides]

# Converting train set - comment out if using validation
X_train = train.drop(columns=drop_cols)
y_train = train[major_oxides]

# Converting test set
X_test = test.drop(columns=drop_cols)
y_test = test[major_oxides]

# %%
import datetime

mlflow.set_experiment(f'SVM_Norm{norm}_{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}')
# Out:
# 2024/03/07 13:53:14 INFO mlflow.tracking.fluent: Experiment with name 'SVM_Norm3_20240307-135313' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/441031611857712967', creation_time=1709815995653, experiment_id='441031611857712967', last_update_time=1709815995653, lifecycle_stage='active', name='SVM_Norm3_20240307-135313', tags={}>

# %%
from sklearn.svm import SVR
import warnings

# disable warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

models = []

kernel="poly"
C=100
eps=0.1
gamma="scale"
degree=2
coef0=1.0


for target in y_train.columns:
    with mlflow.start_run(run_name=f"SVM_{target}"):
        svm_reg = SVR(kernel=kernel, degree=degree, C=C, epsilon=eps, coef0=coef0, gamma=gamma)
        svm_reg.fit(X_train, y_train[target])
        
        y_pred = svm_reg.predict(X_test)
        rmse = np.sqrt(mean_squared_error(y_test[target], y_pred))
        mlflow.log_metric("rmse", float(rmse))
        mlflow.log_param("target", target)
        mlflow.log_param("norm", norm)
        mlflow.log_param("kernel", kernel)
        mlflow.log_param("degree", degree)
        mlflow.log_param("coef0", coef0)
        mlflow.log_param("C", C)
        mlflow.log_param("epsilon", eps)
        mlflow.log_param("gamma", gamma)

        models.append(svm_reg)
        mlflow.sklearn.log_model(svm_reg, f"model_{target}")

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from scipy.stats import expon

# grid search pca hyperparameters
from sklearn.model_selection import RandomizedSearchCV

# Define the parameter distributions (or specific lists) you want to sample from
param_distributions = {
    "pca__n_components": [0.85, 0.90, 0.95, 0.99, 2, 5, 10, 15, 20],
    "svr__kernel": ["poly", "rbf", "sigmoid"],
    "svr__C": expon(scale=100),  # Continuous distribution for C
    "svr__epsilon": [0.1, 0.01, 0.001],
    "svr__degree": [2, 3, 4, 5],
    "svr__coef0": [0.0, 0.1, 0.5, 1.0],
    "svr__gamma": ["scale", "auto", 0.1, 0.01, 0.001],
}

# Setup RandomizedSearchCV
rscv = RandomizedSearchCV(
    estimator=make_pipeline(PCA(), SVR()),
    param_distributions=param_distributions,
    n_iter=100,  # Number of parameter settings that are sampled. Adjust based on your computational budget
    cv=2,
    n_jobs=-1,
    verbose=2,
    random_state=42
)

pca_models = []

for target in y_train.columns:
    with mlflow.start_run(run_name=f"SVM_PCA_{target}"):
        svm_reg = SVR(kernel=kernel, degree=degree, C=C, epsilon=eps, coef0=coef0, gamma=gamma)
        rscv.fit(X_train, y_train[target])
        best_estimator = rscv.best_estimator_
        
        y_pred = best_estimator.predict(X_test)
        rmse = np.sqrt(mean_squared_error(y_test[target], y_pred))
        mlflow.log_metric("rmse", float(rmse))
        
        # log best params from grid search
        mlflow.log_params(rscv.best_params_)
        mlflow.log_param("target", target)
        mlflow.log_param("norm", norm)

        pca_models.append(best_estimator)
        mlflow.sklearn.log_model(best_estimator, f"model_{target}")
# Out:
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# [CV] END pca__n_components=10, svr__C=159.23005340557225, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.0s
# [CV] END pca__n_components=10, svr__C=159.23005340557225, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=5, svr__C=5.806520264207262, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   1.3s
# [CV] END pca__n_components=5, svr__C=5.806520264207262, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   2.1s
# [CV] END pca__n_components=10, svr__C=94.15999701070139, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   1.6s
# [CV] END pca__n_components=15, svr__C=140.79733016874118, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=10, svr__C=94.15999701070139, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   2.1s
# [CV] END pca__n_components=15, svr__C=140.79733016874118, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=0.95, svr__C=10.533264473289401, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   7.2s
# [CV] END pca__n_components=0.95, svr__C=10.533264473289401, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   7.1s
# [CV] END pca__n_components=0.95, svr__C=114.03958033876012, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=   7.7s
# [CV] END pca__n_components=0.95, svr__C=48.201465977050354, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly; total time=   8.1s
# [CV] END pca__n_components=0.9, svr__C=48.68104805084566, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   7.5s
# [CV] END pca__n_components=15, svr__C=84.50031023056181, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly; total time=   1.3s
# [CV] END pca__n_components=15, svr__C=84.50031023056181, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly; total time=   1.5s
# [CV] END pca__n_components=0.9, svr__C=48.68104805084566, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   8.1s
# [CV] END pca__n_components=0.95, svr__C=114.03958033876012, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=   8.7s
# [CV] END pca__n_components=20, svr__C=35.13655007312834, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=   1.4s
# [CV] END pca__n_components=20, svr__C=35.13655007312834, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=   1.3s
# [CV] END pca__n_components=15, svr__C=0.5537420375935475, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.2s
# [CV] END pca__n_components=15, svr__C=0.5537420375935475, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=20, svr__C=97.63011917123741, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.2s
# [CV] END pca__n_components=20, svr__C=97.63011917123741, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.4s
# [CV] END pca__n_components=15, svr__C=32.11999639276417, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=0.85, svr__C=36.27537294604771, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=  10.8s
# [CV] END pca__n_components=0.95, svr__C=48.201465977050354, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly; total time=  11.1s
# [CV] END pca__n_components=15, svr__C=32.11999639276417, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=0.85, svr__C=36.27537294604771, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=  11.6s
# [CV] END pca__n_components=0.9, svr__C=149.22453771381407, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf; total time=   7.4s
# [CV] END pca__n_components=2, svr__C=28.673882298329833, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   1.2s
# [CV] END pca__n_components=2, svr__C=28.673882298329833, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=0.9, svr__C=77.58597359502014, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   6.6s
# [CV] END pca__n_components=10, svr__C=34.21403038870571, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   1.4s
# [CV] END pca__n_components=10, svr__C=34.21403038870571, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   1.9s
# [CV] END pca__n_components=0.9, svr__C=77.58597359502014, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   7.6s
# [CV] END pca__n_components=20, svr__C=11.148395887147208, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=20, svr__C=11.148395887147208, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf; total time=   1.2s
# [CV] END pca__n_components=0.9, svr__C=149.22453771381407, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf; total time=  11.3s
# [CV] END pca__n_components=0.85, svr__C=93.13027879935728, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=sigmoid; total time=   6.5s
# [CV] END pca__n_components=0.85, svr__C=93.13027879935728, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=sigmoid; total time=   7.2s
# [CV] END pca__n_components=20, svr__C=170.3829726638945, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=20, svr__C=170.3829726638945, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   1.3s
# [CV] END pca__n_components=2, svr__C=117.90721902483017, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=rbf; total time=   1.0s
# [CV] END pca__n_components=15, svr__C=121.40869768808548, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   1.1s
# [CV] END pca__n_components=10, svr__C=68.76592784638473, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.0s
# [CV] END pca__n_components=0.95, svr__C=143.0392753076864, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   6.4s
# [CV] END pca__n_components=15, svr__C=121.40869768808548, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   1.2s
# [CV] END pca__n_components=2, svr__C=117.90721902483017, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=rbf; total time=   1.7s
# [CV] END pca__n_components=10, svr__C=68.76592784638473, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=10, svr__C=226.42426492862313, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=   3.3s
# [CV] END pca__n_components=15, svr__C=27.133317233580577, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=0.95, svr__C=143.0392753076864, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   7.5s
# [CV] END pca__n_components=15, svr__C=27.133317233580577, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=5, svr__C=50.886827802519676, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=5, svr__C=50.886827802519676, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.6s
# [CV] END pca__n_components=10, svr__C=226.42426492862313, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=   4.4s
# [CV] END pca__n_components=5, svr__C=119.01119999474501, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=5, svr__C=119.01119999474501, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=0.95, svr__C=3.1933681293053824, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   8.8s
# [CV] END pca__n_components=0.95, svr__C=3.1933681293053824, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   9.5s
# [CV] END pca__n_components=20, svr__C=23.454785986219882, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.5s
# [CV] END pca__n_components=20, svr__C=23.454785986219882, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.4s
# [CV] END pca__n_components=20, svr__C=72.69850610302966, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.3s
# [CV] END pca__n_components=20, svr__C=72.69850610302966, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   2.1s
# [CV] END pca__n_components=2, svr__C=214.24779867144665, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=2, svr__C=214.24779867144665, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=0.85, svr__C=375.5658599101897, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   6.7s
# [CV] END pca__n_components=0.85, svr__C=27.386055214207705, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   6.7s
# [CV] END pca__n_components=0.85, svr__C=27.386055214207705, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   7.2s
# [CV] END pca__n_components=20, svr__C=108.9162387290241, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=rbf; total time=   1.4s
# [CV] END pca__n_components=20, svr__C=108.9162387290241, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=5, svr__C=59.49759030314821, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.2s
# [CV] END pca__n_components=0.95, svr__C=165.81085759775226, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=poly; total time=   6.8s
# [CV] END pca__n_components=2, svr__C=19.701624792324704, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   0.9s
# [CV] END pca__n_components=5, svr__C=59.49759030314821, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=0.95, svr__C=165.81085759775226, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=poly; total time=   7.4s
# [CV] END pca__n_components=2, svr__C=19.701624792324704, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=0.85, svr__C=375.5658599101897, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=  10.4s
# [CV] END pca__n_components=5, svr__C=236.551198250572, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.2s
# [CV] END pca__n_components=5, svr__C=236.551198250572, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=0.85, svr__C=17.62942146834115, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf; total time=   7.5s
# [CV] END pca__n_components=0.85, svr__C=17.62942146834115, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf; total time=   7.7s
# [CV] END pca__n_components=0.95, svr__C=194.0196545963571, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   8.1s
# [CV] END pca__n_components=2, svr__C=214.98126962735108, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=0.85, svr__C=50.678715783717834, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly; total time=  12.2s
# [CV] END pca__n_components=0.85, svr__C=50.678715783717834, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly; total time=  12.4s
# [CV] END pca__n_components=2, svr__C=84.9315656167179, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=2, svr__C=214.98126962735108, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly; total time=   1.6s
# [CV] END pca__n_components=2, svr__C=84.9315656167179, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   1.0s
# [CV] END pca__n_components=0.85, svr__C=78.20663337722502, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=sigmoid; total time=   7.0s
# [CV] END pca__n_components=10, svr__C=31.262368712381218, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=rbf; total time=   1.6s
# [CV] END pca__n_components=5, svr__C=119.08255977579371, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=10, svr__C=31.262368712381218, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=rbf; total time=   1.7s
# [CV] END pca__n_components=5, svr__C=119.08255977579371, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=sigmoid; total time=   1.7s
# [CV] END pca__n_components=0.95, svr__C=194.0196545963571, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=  11.2s
# [CV] END pca__n_components=10, svr__C=34.75620842670952, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=poly; total time=   1.3s
# [CV] END pca__n_components=0.85, svr__C=21.72148953252385, svr__coef0=0.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=sigmoid; total time=   7.8s
# [CV] END pca__n_components=15, svr__C=244.46159618366363, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.2s
# [CV] END pca__n_components=10, svr__C=34.75620842670952, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=poly; total time=   1.7s
# [CV] END pca__n_components=0.85, svr__C=21.72148953252385, svr__coef0=0.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=sigmoid; total time=   7.8s
# [CV] END pca__n_components=0.85, svr__C=4.458298710548632, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf; total time=   7.6s
# [CV] END pca__n_components=15, svr__C=244.46159618366363, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.8s
# [CV] END pca__n_components=0.85, svr__C=78.20663337722502, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=sigmoid; total time=   9.4s
# [CV] END pca__n_components=10, svr__C=2.8005284605107366, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=10, svr__C=2.8005284605107366, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   1.2s
# [CV] END pca__n_components=0.85, svr__C=4.458298710548632, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf; total time=   8.4s
# [CV] END pca__n_components=5, svr__C=89.36325301461753, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly; total time=   1.0s
# [CV] END pca__n_components=5, svr__C=89.36325301461753, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly; total time=   1.6s
# [CV] END pca__n_components=2, svr__C=8.433093616540734, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   1.8s
# [CV] END pca__n_components=2, svr__C=8.433093616540734, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   1.7s
# [CV] END pca__n_components=0.9, svr__C=38.94206578010433, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf; total time=   6.8s
# [CV] END pca__n_components=2, svr__C=101.68588434762378, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=rbf; total time=   1.1s
# [CV] END pca__n_components=0.9, svr__C=38.94206578010433, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf; total time=   8.5s
# [CV] END pca__n_components=0.99, svr__C=104.97190748878002, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   7.9s
# [CV] END pca__n_components=2, svr__C=101.68588434762378, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=rbf; total time=   1.1s
# [CV] END pca__n_components=10, svr__C=4.889210344129426, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=0.99, svr__C=104.97190748878002, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   8.0s
# [CV] END pca__n_components=10, svr__C=4.889210344129426, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=rbf; total time=   1.4s
# [CV] END pca__n_components=20, svr__C=41.83674870461437, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   1.4s
# [CV] END pca__n_components=0.95, svr__C=158.56539797326863, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   7.6s
# [CV] END pca__n_components=0.99, svr__C=52.99301333993761, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   7.8s
# [CV] END pca__n_components=0.95, svr__C=158.56539797326863, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   8.1s
# [CV] END pca__n_components=20, svr__C=41.83674870461437, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   1.8s
# [CV] END pca__n_components=0.85, svr__C=175.94994861571635, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   8.6s
# [CV] END pca__n_components=5, svr__C=100.81145360409121, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   1.0s
# [CV] END pca__n_components=0.99, svr__C=52.99301333993761, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   9.6s
# [CV] END pca__n_components=5, svr__C=100.81145360409121, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=0.85, svr__C=175.94994861571635, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=  10.9s
# [CV] END pca__n_components=0.85, svr__C=58.402775199144706, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=poly; total time=  10.5s
# [CV] END pca__n_components=0.99, svr__C=19.277229993834933, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=sigmoid; total time=   7.5s
# [CV] END pca__n_components=0.85, svr__C=58.402775199144706, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=poly; total time=  12.5s
# [CV] END pca__n_components=0.99, svr__C=19.019471280022497, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   7.6s
# [CV] END pca__n_components=0.99, svr__C=19.019471280022497, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   8.5s
# [CV] END pca__n_components=0.9, svr__C=2.6869072667394427, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=rbf; total time=   7.6s
# [CV] END pca__n_components=0.95, svr__C=69.94394526077897, svr__coef0=0.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=   8.3s
# [CV] END pca__n_components=0.99, svr__C=19.277229993834933, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=sigmoid; total time=  10.5s
# [CV] END pca__n_components=15, svr__C=48.6778131360035, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=sigmoid; total time=   1.5s
# [CV] END pca__n_components=0.9, svr__C=2.6869072667394427, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=rbf; total time=   8.8s
# [CV] END pca__n_components=15, svr__C=48.6778131360035, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=sigmoid; total time=   2.2s
# [CV] END pca__n_components=0.95, svr__C=69.94394526077897, svr__coef0=0.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=  10.2s
# [CV] END pca__n_components=20, svr__C=68.52533277464147, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=sigmoid; total time=   2.0s
# [CV] END pca__n_components=15, svr__C=132.82935787644004, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   1.2s
# [CV] END pca__n_components=20, svr__C=68.52533277464147, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.4s
# [CV] END pca__n_components=0.95, svr__C=103.08271578449819, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   9.8s
# [CV] END pca__n_components=15, svr__C=132.82935787644004, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   1.2s
# [CV] END pca__n_components=2, svr__C=138.87563960054248, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf; total time=   1.0s
# [CV] END pca__n_components=2, svr__C=138.87563960054248, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf; total time=   1.5s
# [CV] END pca__n_components=0.95, svr__C=171.7172598490204, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=poly; total time=   8.1s
# [CV] END pca__n_components=0.95, svr__C=171.7172598490204, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=poly; total time=   6.7s
# [CV] END pca__n_components=10, svr__C=138.97847164954612, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=   1.9s
# [CV] END pca__n_components=0.95, svr__C=103.08271578449819, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=  11.3s
# [CV] END pca__n_components=10, svr__C=138.97847164954612, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=   3.3s
# [CV] END pca__n_components=0.9, svr__C=3.9742506866588965, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   7.8s
# [CV] END pca__n_components=0.9, svr__C=3.9742506866588965, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   8.6s
# [CV] END pca__n_components=2, svr__C=68.20495965733559, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=20, svr__C=80.67707465945907, svr__coef0=0.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   2.1s
# [CV] END pca__n_components=2, svr__C=68.20495965733559, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=poly; total time=   1.1s[CV] END pca__n_components=20, svr__C=80.67707465945907, svr__coef0=0.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   2.0s
#
# [CV] END pca__n_components=0.85, svr__C=149.7954503343587, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly; total time=   6.5s
# [CV] END pca__n_components=0.99, svr__C=175.133255752333, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   6.7s
# [CV] END pca__n_components=0.99, svr__C=175.133255752333, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   7.8s
# [CV] END pca__n_components=0.99, svr__C=85.19972910552637, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=   7.1s
# [CV] END pca__n_components=0.99, svr__C=1.0896806615175478, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   7.7s
# [CV] END pca__n_components=0.85, svr__C=149.7954503343587, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly; total time=   9.8s
# [CV] END pca__n_components=0.99, svr__C=85.19972910552637, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=   7.8s
# [CV] END pca__n_components=10, svr__C=426.8773939601984, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=10, svr__C=426.8773939601984, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=0.95, svr__C=218.66186642208012, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=   8.6s
# [CV] END pca__n_components=0.85, svr__C=10.660871224538544, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=poly; total time=   8.3s
# [CV] END pca__n_components=0.9, svr__C=222.4669958786318, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf; total time=   6.7s
# [CV] END pca__n_components=0.99, svr__C=1.0896806615175478, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=  14.4s
# [CV] END pca__n_components=0.95, svr__C=87.06135442465718, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=   6.8s
# [CV] END pca__n_components=0.95, svr__C=87.06135442465718, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=   8.7s
# [CV] END pca__n_components=20, svr__C=46.97965779202672, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf; total time=   1.6s
# [CV] END pca__n_components=20, svr__C=46.97965779202672, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf; total time=   1.4s
# [CV] END pca__n_components=0.95, svr__C=11.788020797188024, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   7.0s
# [CV] END pca__n_components=0.95, svr__C=150.12425404546258, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   7.5s
# [CV] END pca__n_components=2, svr__C=4.43707665719153, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=2, svr__C=4.43707665719153, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=0.95, svr__C=218.66186642208012, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=  13.1s
# [CV] END pca__n_components=0.95, svr__C=150.12425404546258, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   8.6s
# [CV] END pca__n_components=0.85, svr__C=10.660871224538544, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=poly; total time=  13.3s
# [CV] END pca__n_components=0.9, svr__C=222.4669958786318, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf; total time=  12.7s
# [CV] END pca__n_components=15, svr__C=50.173671764138504, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=15, svr__C=50.173671764138504, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   1.9s
# [CV] END pca__n_components=15, svr__C=43.595353461673334, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.9s
# [CV] END pca__n_components=5, svr__C=3.2849640758686722, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=15, svr__C=43.595353461673334, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.9s
# [CV] END pca__n_components=0.99, svr__C=12.649099593117121, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   7.0s
# [CV] END pca__n_components=5, svr__C=3.2849640758686722, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.7s
# [CV] END pca__n_components=0.95, svr__C=11.788020797188024, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   7.9s
# [CV] END pca__n_components=0.99, svr__C=12.649099593117121, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   7.6s
# [CV] END pca__n_components=15, svr__C=209.2822556887118, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=15, svr__C=209.2822556887118, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   1.4s
# [CV] END pca__n_components=0.95, svr__C=348.3575221256005, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   6.1s
# [CV] END pca__n_components=0.95, svr__C=348.3575221256005, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   5.7s
# [CV] END pca__n_components=0.85, svr__C=98.76741730080221, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=sigmoid; total time=   5.5s
# [CV] END pca__n_components=0.85, svr__C=98.76741730080221, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=sigmoid; total time=   5.4s
# [CV] END pca__n_components=0.95, svr__C=172.89945113672715, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   3.6s
# [CV] END pca__n_components=0.95, svr__C=172.89945113672715, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   3.4s
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# [CV] END pca__n_components=10, svr__C=159.23005340557225, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=5, svr__C=5.806520264207262, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   2.0s
# [CV] END pca__n_components=10, svr__C=159.23005340557225, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=   2.0s
# [CV] END pca__n_components=5, svr__C=5.806520264207262, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   2.0s
# [CV] END pca__n_components=10, svr__C=94.15999701070139, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   3.3s
# [CV] END pca__n_components=10, svr__C=94.15999701070139, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   3.7s
# [CV] END pca__n_components=0.95, svr__C=114.03958033876012, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=   6.5s
# [CV] END pca__n_components=15, svr__C=140.79733016874118, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=15, svr__C=140.79733016874118, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=rbf; total time=   1.1s
# [CV] END pca__n_components=0.9, svr__C=48.68104805084566, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   6.1s
# [CV] END pca__n_components=0.95, svr__C=10.533264473289401, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   7.7s
# [CV] END pca__n_components=0.95, svr__C=10.533264473289401, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   8.0s
# [CV] END pca__n_components=15, svr__C=84.50031023056181, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=15, svr__C=84.50031023056181, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly; total time=   1.2s
# [CV] END pca__n_components=0.85, svr__C=36.27537294604771, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   8.6s
# [CV] END pca__n_components=0.85, svr__C=36.27537294604771, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   8.8s
# [CV] END pca__n_components=0.95, svr__C=48.201465977050354, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly; total time=   9.0s
# [CV] END pca__n_components=20, svr__C=35.13655007312834, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=   1.6s
# [CV] END pca__n_components=20, svr__C=35.13655007312834, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=   1.5s
# [CV] END pca__n_components=15, svr__C=0.5537420375935475, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.5s
# [CV] END pca__n_components=0.95, svr__C=48.201465977050354, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly; total time=  10.5s
# [CV] END pca__n_components=15, svr__C=0.5537420375935475, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.9s
# [CV] END pca__n_components=20, svr__C=97.63011917123741, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.2s
# [CV] END pca__n_components=20, svr__C=97.63011917123741, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.4s
# [CV] END pca__n_components=0.95, svr__C=114.03958033876012, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=  11.9s
# [CV] END pca__n_components=15, svr__C=32.11999639276417, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=sigmoid; total time=   2.1s
# [CV] END pca__n_components=0.9, svr__C=149.22453771381407, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf; total time=   6.3s
# [CV] END pca__n_components=15, svr__C=32.11999639276417, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=sigmoid; total time=   2.3s
# [CV] END pca__n_components=0.9, svr__C=48.68104805084566, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=  11.1s
# [CV] END pca__n_components=2, svr__C=28.673882298329833, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   1.0s
# [CV] END pca__n_components=10, svr__C=34.21403038870571, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   1.0s
# [CV] END pca__n_components=0.9, svr__C=149.22453771381407, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf; total time=   8.1s
# [CV] END pca__n_components=2, svr__C=28.673882298329833, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   2.5s
# [CV] END pca__n_components=0.9, svr__C=77.58597359502014, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   7.5s
# [CV] END pca__n_components=10, svr__C=34.21403038870571, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   2.6s
# [CV] END pca__n_components=0.9, svr__C=77.58597359502014, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   8.2s
# [CV] END pca__n_components=20, svr__C=11.148395887147208, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf; total time=   1.1s
# [CV] END pca__n_components=20, svr__C=11.148395887147208, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=2, svr__C=117.90721902483017, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=rbf; total time=   0.9s
# [CV] END pca__n_components=20, svr__C=170.3829726638945, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   1.3s
# [CV] END pca__n_components=2, svr__C=117.90721902483017, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=rbf; total time=   0.9s
# [CV] END pca__n_components=20, svr__C=170.3829726638945, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   1.2s
# [CV] END pca__n_components=0.95, svr__C=143.0392753076864, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   5.9s
# [CV] END pca__n_components=0.85, svr__C=93.13027879935728, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=sigmoid; total time=   8.1s
# [CV] END pca__n_components=15, svr__C=121.40869768808548, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   0.8s
# [CV] END pca__n_components=0.85, svr__C=93.13027879935728, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=sigmoid; total time=   9.1s
# [CV] END pca__n_components=10, svr__C=68.76592784638473, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=10, svr__C=68.76592784638473, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.2s
# [CV] END pca__n_components=0.95, svr__C=3.1933681293053824, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   5.8s
# [CV] END pca__n_components=0.95, svr__C=143.0392753076864, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   7.0s
# [CV] END pca__n_components=15, svr__C=121.40869768808548, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   2.1s
# [CV] END pca__n_components=15, svr__C=27.133317233580577, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   1.1s
# [CV] END pca__n_components=15, svr__C=27.133317233580577, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   1.1s
# [CV] END pca__n_components=5, svr__C=50.886827802519676, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   0.9s
# [CV] END pca__n_components=0.95, svr__C=3.1933681293053824, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   7.7s
# [CV] END pca__n_components=5, svr__C=50.886827802519676, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.0s
# [CV] END pca__n_components=5, svr__C=119.01119999474501, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=5, svr__C=119.01119999474501, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.9s
# [CV] END pca__n_components=20, svr__C=23.454785986219882, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=0.85, svr__C=375.5658599101897, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   4.8s
# [CV] END pca__n_components=0.85, svr__C=27.386055214207705, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   4.9s
# [CV] END pca__n_components=20, svr__C=23.454785986219882, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.7s
# [CV] END pca__n_components=20, svr__C=72.69850610302966, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.2s
# [CV] END pca__n_components=20, svr__C=72.69850610302966, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=2, svr__C=214.24779867144665, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=sigmoid; total time=   0.9s
# [CV] END pca__n_components=2, svr__C=214.24779867144665, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=sigmoid; total time=   1.7s
# [CV] END pca__n_components=0.95, svr__C=165.81085759775226, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=poly; total time=   5.4s
# [CV] END pca__n_components=0.95, svr__C=165.81085759775226, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=poly; total time=   6.9s
# [CV] END pca__n_components=20, svr__C=108.9162387290241, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=rbf; total time=   1.4s
# [CV] END pca__n_components=0.85, svr__C=50.678715783717834, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly; total time=   6.9s
# [CV] END pca__n_components=0.85, svr__C=50.678715783717834, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly; total time=   7.1s
# [CV] END pca__n_components=0.85, svr__C=375.5658599101897, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   9.5s[CV] END pca__n_components=5, svr__C=59.49759030314821, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   0.8s
#
# [CV] END pca__n_components=20, svr__C=108.9162387290241, svr__coef0=0.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=rbf; total time=   1.1s
# [CV] END pca__n_components=5, svr__C=59.49759030314821, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   0.9s
# [CV] END pca__n_components=10, svr__C=226.42426492862313, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=  12.0s
# [CV] END pca__n_components=0.85, svr__C=27.386055214207705, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   9.3s
# [CV] END pca__n_components=2, svr__C=19.701624792324704, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   0.9s
# [CV] END pca__n_components=2, svr__C=19.701624792324704, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   0.9s
# [CV] END pca__n_components=5, svr__C=236.551198250572, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.1s
# [CV] END pca__n_components=5, svr__C=236.551198250572, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=0.95, svr__C=194.0196545963571, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   5.9s
# [CV] END pca__n_components=0.95, svr__C=194.0196545963571, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   6.9s
# [CV] END pca__n_components=2, svr__C=214.98126962735108, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=0.85, svr__C=17.62942146834115, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf; total time=   6.6s
# [CV] END pca__n_components=2, svr__C=214.98126962735108, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly; total time=   1.6s
# [CV] END pca__n_components=2, svr__C=84.9315656167179, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=2, svr__C=84.9315656167179, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=poly; total time=   1.1s
# [CV] END pca__n_components=10, svr__C=31.262368712381218, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=rbf; total time=   2.0s
# [CV] END pca__n_components=5, svr__C=119.08255977579371, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=sigmoid; total time=   1.2s
# [CV] END pca__n_components=5, svr__C=119.08255977579371, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=sigmoid; total time=   1.2s
# [CV] END pca__n_components=10, svr__C=31.262368712381218, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=rbf; total time=   2.1s
# [CV] END pca__n_components=10, svr__C=34.75620842670952, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=poly; total time=   1.4s
# [CV] END pca__n_components=0.85, svr__C=17.62942146834115, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf; total time=   9.6s
# ...
# [CV] END pca__n_components=0.85, svr__C=4.458298710548632, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf; total time=   7.3s
# [CV] END pca__n_components=10, svr__C=2.8005284605107366, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   1.3s
# [CV] END pca__n_components=0.85, svr__C=17.62942146834115, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf; total time=  10.8s
# [CV] END pca__n_components=5, svr__C=89.36325301461753, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly; total time=   1.3s
# [CV] END pca__n_components=5, svr__C=89.36325301461753, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly; total time=   2.5s
# [CV] END pca__n_components=0.85, svr__C=4.458298710548632, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf; total time=  12.2s
# [CV] END pca__n_components=0.99, svr__C=104.97190748878002, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   6.6s
# [CV] END pca__n_components=2, svr__C=8.433093616540734, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   3.2s
# [CV] END pca__n_components=2, svr__C=8.433093616540734, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   1.0s
# [CV] END pca__n_components=0.99, svr__C=104.97190748878002, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   6.8s
# [CV] END pca__n_components=0.9, svr__C=38.94206578010433, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf; total time=   8.4s
# [CV] END pca__n_components=2, svr__C=101.68588434762378, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=rbf; total time=   1.0s
# [CV] END pca__n_components=2, svr__C=101.68588434762378, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=rbf; total time=   1.2s
# [CV] END pca__n_components=10, svr__C=4.889210344129426, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=0.85, svr__C=175.94994861571635, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   7.2s
# [CV] END pca__n_components=10, svr__C=4.889210344129426, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.001, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=0.95, svr__C=158.56539797326863, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   7.8s
# [CV] END pca__n_components=0.99, svr__C=52.99301333993761, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   8.6s
# [CV] END pca__n_components=20, svr__C=41.83674870461437, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   2.0s
# [CV] END pca__n_components=20, svr__C=41.83674870461437, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   2.1s
# [CV] END pca__n_components=0.95, svr__C=158.56539797326863, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=poly; total time=   9.5s
# [CV] END pca__n_components=0.85, svr__C=175.94994861571635, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=  10.6s
# [CV] END pca__n_components=5, svr__C=100.81145360409121, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   1.4s
# [CV] END pca__n_components=0.9, svr__C=38.94206578010433, svr__coef0=1.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf; total time=  13.9s
# [CV] END pca__n_components=5, svr__C=100.81145360409121, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   3.1s
# [CV] END pca__n_components=0.99, svr__C=52.99301333993761, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=  13.0s
# [CV] END pca__n_components=0.99, svr__C=19.277229993834933, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=sigmoid; total time=   7.3s
# [CV] END pca__n_components=0.99, svr__C=19.277229993834933, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=sigmoid; total time=   6.6s
# [CV] END pca__n_components=0.99, svr__C=19.019471280022497, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   6.9s
# [CV] END pca__n_components=0.95, svr__C=69.94394526077897, svr__coef0=0.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=   6.3s
# [CV] END pca__n_components=0.99, svr__C=19.019471280022497, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   7.9s
# [CV] END pca__n_components=0.85, svr__C=58.402775199144706, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=poly; total time=  12.4s
# [CV] END pca__n_components=15, svr__C=48.6778131360035, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=sigmoid; total time=   1.5s
# [CV] END pca__n_components=0.9, svr__C=2.6869072667394427, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=rbf; total time=   8.3s
# [CV] END pca__n_components=15, svr__C=48.6778131360035, svr__coef0=0.1, svr__degree=3, svr__epsilon=0.01, svr__gamma=auto, svr__kernel=sigmoid; total time=   1.3s
# [CV] END pca__n_components=0.9, svr__C=2.6869072667394427, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=rbf; total time=   7.8s
# [CV] END pca__n_components=20, svr__C=68.52533277464147, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.6s
# [CV] END pca__n_components=20, svr__C=68.52533277464147, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=sigmoid; total time=   1.5s
# [CV] END pca__n_components=15, svr__C=132.82935787644004, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   1.5s
# [CV] END pca__n_components=15, svr__C=132.82935787644004, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   1.4s
# [CV] END pca__n_components=0.95, svr__C=69.94394526077897, svr__coef0=0.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=  10.7s
# [CV] END pca__n_components=0.95, svr__C=171.7172598490204, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=poly; total time=   6.5s
# [CV] END pca__n_components=2, svr__C=138.87563960054248, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf; total time=   1.1s
# [CV] END pca__n_components=0.9, svr__C=3.9742506866588965, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   6.0s
# [CV] END pca__n_components=2, svr__C=138.87563960054248, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf; total time=   1.2s
# [CV] END pca__n_components=0.9, svr__C=3.9742506866588965, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=rbf; total time=   6.6s
# [CV] END pca__n_components=10, svr__C=138.97847164954612, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=   2.8s
# [CV] END pca__n_components=10, svr__C=138.97847164954612, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=poly; total time=   3.0s
# [CV] END pca__n_components=0.95, svr__C=103.08271578449819, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=  14.0s
# [CV] END pca__n_components=0.85, svr__C=149.7954503343587, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly; total time=   6.1s
# [CV] END pca__n_components=0.95, svr__C=171.7172598490204, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.001, svr__gamma=0.01, svr__kernel=poly; total time=  12.1s
# [CV] END pca__n_components=0.95, svr__C=103.08271578449819, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=  14.3s
# [CV] END pca__n_components=0.85, svr__C=149.7954503343587, svr__coef0=1.0, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly; total time=   7.2s
# [CV] END pca__n_components=0.99, svr__C=175.133255752333, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   6.5s
# [CV] END pca__n_components=20, svr__C=80.67707465945907, svr__coef0=0.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.4s
# [CV] END pca__n_components=0.99, svr__C=175.133255752333, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.001, svr__gamma=0.1, svr__kernel=poly; total time=   7.2s
# [CV] END pca__n_components=2, svr__C=68.20495965733559, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=poly; total time=   1.6s
# [CV] END pca__n_components=0.99, svr__C=1.0896806615175478, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   7.2s
# [CV] END pca__n_components=20, svr__C=80.67707465945907, svr__coef0=0.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   2.1s
# [CV] END pca__n_components=2, svr__C=68.20495965733559, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=poly; total time=   2.2s
# [CV] END pca__n_components=0.99, svr__C=85.19972910552637, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=   6.6s
# [CV] END pca__n_components=0.99, svr__C=85.19972910552637, svr__coef0=0.5, svr__degree=5, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=sigmoid; total time=   7.4s
# [CV] END pca__n_components=0.99, svr__C=1.0896806615175478, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf; total time=   8.4s
# [CV] END pca__n_components=10, svr__C=426.8773939601984, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.5s
# [CV] END pca__n_components=10, svr__C=426.8773939601984, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.2s
# [CV] END pca__n_components=0.85, svr__C=58.402775199144706, svr__coef0=1.0, svr__degree=3, svr__epsilon=0.01, svr__gamma=scale, svr__kernel=poly; total time=  28.4s
# [CV] END pca__n_components=0.95, svr__C=218.66186642208012, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=   7.2s
# [CV] END pca__n_components=0.95, svr__C=218.66186642208012, svr__coef0=0.5, svr__degree=4, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=   6.8s
# [CV] END pca__n_components=0.85, svr__C=10.660871224538544, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=poly; total time=   6.9s
# [CV] END pca__n_components=0.85, svr__C=10.660871224538544, svr__coef0=0.5, svr__degree=3, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=poly; total time=   7.5s
# [CV] END pca__n_components=20, svr__C=46.97965779202672, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf; total time=   1.3s
# [CV] END pca__n_components=0.9, svr__C=222.4669958786318, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf; total time=   8.4s
# [CV] END pca__n_components=20, svr__C=46.97965779202672, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf; total time=   1.5s
# [CV] END pca__n_components=2, svr__C=4.43707665719153, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.2s
# [CV] END pca__n_components=2, svr__C=4.43707665719153, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=sigmoid; total time=   1.0s
# [CV] END pca__n_components=0.9, svr__C=222.4669958786318, svr__coef0=0.1, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf; total time=  10.0s
# [CV] END pca__n_components=0.95, svr__C=87.06135442465718, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=  10.0s
# [CV] END pca__n_components=15, svr__C=50.173671764138504, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   1.2s
# [CV] END pca__n_components=0.95, svr__C=150.12425404546258, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=   8.9s
# [CV] END pca__n_components=0.95, svr__C=11.788020797188024, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   8.6s
# [CV] END pca__n_components=15, svr__C=50.173671764138504, svr__coef0=1.0, svr__degree=5, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   1.2s
# [CV] END pca__n_components=0.99, svr__C=12.649099593117121, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   7.3s
# [CV] END pca__n_components=15, svr__C=43.595353461673334, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.4s
# [CV] END pca__n_components=5, svr__C=3.2849640758686722, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.2s
# [CV] END pca__n_components=0.95, svr__C=87.06135442465718, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly; total time=  12.8s
# [CV] END pca__n_components=0.95, svr__C=11.788020797188024, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=auto, svr__kernel=rbf; total time=   8.8s
# [CV] END pca__n_components=15, svr__C=43.595353461673334, svr__coef0=0.1, svr__degree=5, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   1.7s
# [CV] END pca__n_components=5, svr__C=3.2849640758686722, svr__coef0=0.0, svr__degree=2, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly; total time=   1.0s
# [CV] END pca__n_components=0.95, svr__C=150.12425404546258, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=auto, svr__kernel=rbf; total time=  11.9s
# [CV] END pca__n_components=15, svr__C=209.2822556887118, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   1.6s
# [CV] END pca__n_components=15, svr__C=209.2822556887118, svr__coef0=0.5, svr__degree=2, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   1.6s
# [CV] END pca__n_components=0.85, svr__C=98.76741730080221, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=sigmoid; total time=   6.3s
# [CV] END pca__n_components=0.99, svr__C=12.649099593117121, svr__coef0=0.0, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=sigmoid; total time=   9.8s
# [CV] END pca__n_components=0.85, svr__C=98.76741730080221, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.001, svr__gamma=scale, svr__kernel=sigmoid; total time=   6.1s
# [CV] END pca__n_components=0.95, svr__C=348.3575221256005, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   7.1s
# [CV] END pca__n_components=0.95, svr__C=348.3575221256005, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   7.5s
# [CV] END pca__n_components=0.95, svr__C=172.89945113672715, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   3.1s
# [CV] END pca__n_components=0.95, svr__C=172.89945113672715, svr__coef0=0.1, svr__degree=4, svr__epsilon=0.1, svr__gamma=scale, svr__kernel=rbf; total time=   3.1s

# %%
from datetime import datetime

# Assuming MLflow tracking URI is set elsewhere or using the default
# List all experiments
experiments = mlflow.search_experiments()

# Filter experiments based on the naming pattern 'SVM_Norm'
svm_norm_experiments = [exp for exp in experiments if exp.name.startswith("SVM_Norm")]

# Sort these experiments by their timestamp in the name, assuming the timestamp follows 'SVM_Norm{norm}_{timestamp}'
latest_experiment = sorted(
    svm_norm_experiments,
    key=lambda x: datetime.strptime(x.name.split('_')[-1], "%Y%m%d-%H%M%S"),
    reverse=True
)[0]

# Now, list all runs in the latest experiment using its experiment_id
runs = mlflow.search_runs([latest_experiment.experiment_id])

# %%
data = []
for _, row in runs.iterrows():
    run_name = row['tags.mlflow.runName']  # Adjust based on actual tag used for naming runs
    if run_name.startswith("SVM") or run_name.startswith("SVM_PCA"):
        # Assuming RMSE is stored in metrics with a key such as 'RMSE'
        rmse = row['metrics.rmse']  # Adjust the key based on your actual data structure
        # Extract oxide name from the run name, assuming it follows a recognizable pattern
        # This might need adjustment based on your naming convention
        with_pca = run_name.startswith("SVM_PCA")
        oxide_name = run_name.split('_')[1] if not with_pca else run_name.split('_')[2]  # Example: "SVM_CuOxide_..." -> "CuOxide"
        data.append({'Oxide': oxide_name, 'RMSE': rmse, 'WithPCA': with_pca})

# Convert data to a pandas DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#     Oxide      RMSE  WithPCA
# 0     K2O  1.159734     True
# 1    Na2O  0.632748     True
# 2     CaO  1.650255     True
# 3     MgO  1.840583     True
# 4    FeOT  1.829822     True
# 5   Al2O3  2.254029     True
# 6    TiO2  0.558295     True
# 7    SiO2  4.057205     True
# 8     K2O  0.821610    False
# 9    Na2O  0.471633    False
# 10    CaO  1.551286    False
# 11    MgO  1.268776    False
# 12   FeOT  1.828757    False
# 13  Al2O3  1.801759    False
# 14   TiO2  0.494588    False
# 15   SiO2  3.390499    False

# %%
pivoted_df = df.pivot_table(index='Oxide', columns='WithPCA', values='RMSE', aggfunc='first').rename(columns={True: 'With PCA', False: 'Without PCA'})

# %%
pivoted_df
# Out:
# WithPCA  Without PCA  With PCA
# Oxide
# Al2O3       1.801759  2.254029
# CaO         1.551286  1.650255
# FeOT        1.828757  1.829822
# K2O         0.821610  1.159734
# MgO         1.268776  1.840583
# Na2O        0.471633  0.632748
# SiO2        3.390499  4.057205
# TiO2        0.494588  0.558295
