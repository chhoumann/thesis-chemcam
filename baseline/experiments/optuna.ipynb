# %%
# %load_ext autoreload
# %autoreload 2

# %%
import mlflow
import numpy as np
import pandas as pd
import math
import optuna
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR

from lib.reproduction import major_oxides

# %%
from lib import full_flow_dataloader
from lib.config import AppConfig

mlflow.set_tracking_uri(AppConfig().mlflow_tracking_uri)

drop_cols = ["ID", "Sample Name"]

from sklearn.preprocessing import MaxAbsScaler, PowerTransformer

train_processed, test_processed = full_flow_dataloader.load_full_flow_data(load_cache_if_exits=True, average_shots=True)
target = major_oxides[0]

drop_cols.extend([oxide for oxide in major_oxides if oxide != target])
train_processed = train_processed.drop(columns=drop_cols)
test_processed = test_processed.drop(columns=drop_cols)

# Applying MaxAbsScaler and PowerTransformer
scaler = MaxAbsScaler()
power_transformer = PowerTransformer()

# Exclude target column from normalization
cols_to_normalize = [col for col in train_processed.columns if col not in drop_cols + [target]]

# Normalize only the columns that are not in drop_cols or the target column
train_processed[cols_to_normalize] = scaler.fit_transform(train_processed[cols_to_normalize])
train_processed[cols_to_normalize] = power_transformer.fit_transform(train_processed[cols_to_normalize])

test_processed[cols_to_normalize] = scaler.transform(test_processed[cols_to_normalize])
test_processed[cols_to_normalize] = power_transformer.transform(test_processed[cols_to_normalize])

# Reconstruct the DataFrame to include the target column
train_processed = pd.DataFrame(train_processed, columns=train_processed.columns)
test_processed = pd.DataFrame(test_processed, columns=test_processed.columns)

X_train = train_processed.drop(columns=[target])
y_train = train_processed[target]

X_test = test_processed.drop(columns=[target])
y_test = test_processed[target]

# %%
# https://mlflow.org/docs/latest/traditional-ml/hyperparameter-tuning-with-child-runs/notebooks/hyperparameter-tuning-with-child-runs.html
def get_or_create_experiment(experiment_name: str) -> str:
    """
    Retrieve the ID of an existing MLflow experiment or create a new one if it doesn't exist.

    This function checks if an experiment with the given name exists within MLflow.
    If it does, the function returns its ID. If not, it creates a new experiment
    with the provided name and returns its ID.

    Parameters:
    - experiment_name (str): Name of the MLflow experiment.

    Returns:
    - str: ID of the existing or newly created MLflow experiment.
    """

    if experiment := mlflow.get_experiment_by_name(experiment_name):
        return experiment.experiment_id
    else:
        return mlflow.create_experiment(experiment_name)

# %%
experiment_id = get_or_create_experiment("optuna_experiment")

experiment_id
# Out:
# '202075117645542195'

# %%
mlflow.set_experiment(experiment_id=experiment_id)
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/202075117645542195', creation_time=1713779016259, experiment_id='202075117645542195', last_update_time=1713779016259, lifecycle_stage='active', name='optuna_experiment', tags={}>

# %%
# override Optuna's default logging to ERROR only
optuna.logging.set_verbosity(optuna.logging.ERROR)

# define a logging callback that will report on only new challenger parameter configurations if a
# trial has usurped the state of 'best conditions'


# https://mlflow.org/docs/latest/traditional-ml/hyperparameter-tuning-with-child-runs/notebooks/hyperparameter-tuning-with-child-runs.html
def champion_callback(study, frozen_trial):
    """
    Logging callback that will report when a new trial iteration improves upon existing
    best trial values.

    Note: This callback is not intended for use in distributed computing systems such as Spark
    or Ray due to the micro-batch iterative implementation for distributing trials to a cluster's
    workers or agents.
    The race conditions with file system state management for distributed trials will render
    inconsistent values with this callback.
    """

    winner = study.user_attrs.get("winner", None)

    if study.best_value and winner != study.best_value:
        study.set_user_attr("winner", study.best_value)
        if winner:
            improvement_percent = (abs(winner - study.best_value) / study.best_value) * 100
            print(
                f"Trial {frozen_trial.number} achieved value: {frozen_trial.value} with "
                f"{improvement_percent: .4f}% improvement"
            )
        else:
            print(f"Initial trial {frozen_trial.number} achieved value: {frozen_trial.value}")

# %%
def objective(trial):
    with mlflow.start_run(nested=True):
        # Define hyperparameters
        params = {
            "C": trial.suggest_float("C", 1e-3, 100.0, log=True),
            "epsilon": trial.suggest_float("epsilon", 1e-3, 1.0, log=True),
            "kernel": trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"]),
            "gamma": trial.suggest_categorical("gamma", ["scale", "auto"]),
            "coef0": trial.suggest_float("coef0", 0.0, 10.0),
            "shrinking": trial.suggest_categorical("shrinking", [True, False]),
            "tol": trial.suggest_float("tol", 1e-5, 1e-1, log=True),
            "max_iter": trial.suggest_int("max_iter", -1, 1000)
        }

        if params["kernel"] == "poly":
            params["degree"] = trial.suggest_int("degree", 2, 5)

        # Train SVR model
        model = SVR(
            C=params["C"], 
            epsilon=params["epsilon"], 
            kernel=params["kernel"], 
            degree=params.get("degree", 3),
            gamma=params["gamma"],
            coef0=params["coef0"],
            shrinking=params["shrinking"],
            tol=params["tol"],
            max_iter=params["max_iter"]
        )
        model.fit(X_train, y_train)
        preds = model.predict(X_test)
        error = mean_squared_error(y_test, preds)

        # Log to MLflow
        mlflow.log_params(params)
        mlflow.log_metric("mse", float(error))
        mlflow.log_metric("rmse", math.sqrt(error))

    return error

# %%
run_name = f"SVR_{target}"

# %%
# Initiate the parent run and call the hyperparameter tuning child run logic
with mlflow.start_run(experiment_id=experiment_id, run_name=run_name, nested=True):
    # Initialize the Optuna study
    study = optuna.create_study(direction="minimize")

    # Execute the hyperparameter optimization trials.
    # Note the addition of the `champion_callback` inclusion to control our logging
    study.optimize(objective, n_trials=500, callbacks=[champion_callback])

    mlflow.log_params(study.best_params)
    mlflow.log_metric("best_mse", study.best_value)
    mlflow.log_metric("best_rmse", math.sqrt(study.best_value))

    # Log tags
    mlflow.set_tags(
        tags={
            "project": "Stacking SVR",
            "optimizer_engine": "optuna",
            "model_family": "SVR",
            "feature_set_version": 1,
        }
    )

    # Log a fit model instance
    model = SVR(**study.best_params)

    artifact_path = "model"
    
    mlflow.sklearn.log_model(
        model,
        artifact_path=artifact_path,
        input_example=train_processed.iloc[[0]],
        serialization_format="pickle",
        registered_model_name="SVR_model_version_1"
    )
    
    # Get the logged model uri so that we can load it from the artifact store
    model_uri = mlflow.get_artifact_uri(artifact_path)
# Out:
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=530).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Initial trial 0 achieved value: 144.777801187849
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=364).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Trial 1 achieved value: 40.38592902511741 with  258.4858% improvement
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=272).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=285).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=17).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=937).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Trial 6 achieved value: 16.40809989895186 with  146.1341% improvement
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=952).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=97).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=807).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=643).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Trial 10 achieved value: 15.128569218008453 with  8.4577% improvement
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=667).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=654).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Trial 12 achieved value: 13.79581254279665 with  9.6606% improvement
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=654).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=714).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=491).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=518).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=777).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=798).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=763).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=592).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=443).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=638).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=737).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=995).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=716).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=890).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=581).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=701).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=448).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=765).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=733).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=604).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=591).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=585).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=349).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=538).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=872).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=688).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=387).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=817).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Trial 41 achieved value: 13.534646415175526 with  1.9296% improvement
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=834).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=903).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=718).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=630).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=187).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=738).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=826).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=662).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=528).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=787).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=948).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=939).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=909).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=989).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=621).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=679).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=866).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Trial 58 achieved value: 13.473205520742633 with  0.4560% improvement
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=743).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=858).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=811).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=804).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=770).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=814).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=776).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=864).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=752).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=704).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=910).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=719).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=920).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=879).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=968).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=876).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=831).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=915).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=852).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=800).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=926).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=7).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=773).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=882).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=844).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=841).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=970).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=838).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=840).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=822).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=961).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=790).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=797).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=855).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Trial 93 achieved value: 13.389866878410318 with  0.6224% improvement
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=855).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=852).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=850).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=931).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=924).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=942).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=995).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=995).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=984).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=998).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=946).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=936).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=899).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=963).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=979).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=950).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=905).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=867).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=928).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=932).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=998).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=895).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=82).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=917).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=952).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=886).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=818).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=973).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=865).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Trial 122 achieved value: 13.287915868838788 with  0.7672% improvement
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=930).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=238).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=916).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=868).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=869).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=951).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=901).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=907).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=860).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=940).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=975).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=920).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=894).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=831).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=840).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=820).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=880).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=858).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=958).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=826).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=933).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=562).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=802).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=788).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=844).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=873).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=806).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=892).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=898).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=837).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=482).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=881).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=756).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=861).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=920).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=984).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=950).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=816).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=891).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=891).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=853).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=894).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=889).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=871).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=830).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=903).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=859).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=860).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=808).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=842).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=887).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=785).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=861).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=897).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=399).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=917).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=873).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=877).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=829).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=848).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=873).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=903).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=832).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=849).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=801).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=807).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=883).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=830).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=774).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=863).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=911).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ...
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=884).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=842).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=904).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=953).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=873).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=925).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=859).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=833).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=897).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=972).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=876).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=938).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=916).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=877).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=807).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=844).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=899).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=949).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=858).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=886).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=370).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=767).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=916).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=827).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=962).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=451).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=872).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=935).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=904).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=790).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=850).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=891).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=926).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=873).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=814).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=977).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=978).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=965).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=978).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=981).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=950).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=940).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=962).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=920).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=908).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=897).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=957).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=883).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=861).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=881).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=886).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=853).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=904).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=874).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=841).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=866).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=893).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=912).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=719).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=980).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/christian/projects/p9/baseline/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=970).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 29
#      25 model = SVR(**study.best_params)
#      27 artifact_path = "model"
# ---> 29 mlflow.sklearn.log_model(
#      30     sklearn_model=model,
#      31     artifact_path=artifact_path,
#      32     input_example=train_processed.iloc[[0]],
#      33     model_format="ubj",
#      34     metadata={"model_data_version": 1},
#      35 )
#      37 # Get the logged model uri so that we can load it from the artifact store
#      38 model_uri = mlflow.get_artifact_uri(artifact_path)
#
# TypeError: log_model() got an unexpected keyword argument 'sklearn_model'
