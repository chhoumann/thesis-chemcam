# %%
import mlflow
from lib.reproduction import major_oxides

# Set MLFlow tracking URI if your MLFlow server is not running locally
# mlflow.set_tracking_uri('your_mlflow_tracking_uri')

experiment_id = "935520882997737302"  # Replace with your MLFlow experiment ID
submodels = ['Low', 'Mid', 'High', 'Full']

# Initialize the dictionary to store the results
results = {oxide: {submodel: [] for submodel in submodels} for oxide in major_oxides}

def fetch_runs(experiment_id):
    # Fetch all runs for the given experiment ID
    runs = mlflow.search_runs(experiment_ids=[experiment_id])
    results = {}  # Initialize the dictionary to store the results
    
    for _, row in runs.iterrows():
        run_id = row['run_id']
        run_name = row['tags.mlflow.runName']
        params = mlflow.get_run(run_id).data.params
        metrics = mlflow.get_run(run_id).data.metrics
        
        # Parse the run name to get the oxide and submodel
        parts = run_name.split('_')
        if len(parts) == 2:
            major_oxide, submodel = parts
            
            # Initialize submodel dictionary if it doesn't exist
            if major_oxide not in results:
                results[major_oxide] = {}
            if submodel not in results[major_oxide]:
                results[major_oxide][submodel] = {}

            # Fetch the metric history for 'outliers_removed'
            metric_history = mlflow.tracking.MlflowClient().get_metric_history(run_id, 'outliers_removed')
            # Sum the values of the 'outliers_removed' metric across all steps
            total_outliers_removed = sum(m.value for m in metric_history)

            # Retrieve the other metrics and the parameter 'n_spectra'
            RMSECV = metrics.get('RMSECV', None)
            RMSECV_MIN = metrics.get('RMSECV_MIN', None)
            RMSEP = metrics.get('RMSEP', None)
            n_spectra = params.get('n_spectra', None)  # n_spectra is retrieved from parameters
            outlier_removal_iterations = metrics.get('outlier_removal_iterations', None)
            
            # Store the metrics, the parameter 'n_spectra', and the total outliers removed in the results dictionary
            results[major_oxide][submodel] = {
                'RMSECV': RMSECV,
                'RMSECV_MIN': RMSECV_MIN,
                'RMSEP': RMSEP,
                'n_spectra': n_spectra,
                'outlier_removal_iterations': outlier_removal_iterations,
                'outliers_removed': total_outliers_removed
            }

    return results

# Fetch runs and print the results
results = fetch_runs(experiment_id)
results
# Out:
# {'K2O': {'High': {'RMSECV': 0.9814821908117807,
#    'RMSECV_MIN': 0.5830669073290804,
#    'RMSEP': 0.7103206230713095,
#    'n_spectra': '920',
#    'outlier_removal_iterations': 2.0,
#    'outliers_removed': 13.0},
#   'Low': {'RMSECV': 0.38695108904609343,
#    'RMSECV_MIN': 0.28119934159319815,
#    'RMSEP': 0.34477671142578986,
#    'n_spectra': '773',
#    'outlier_removal_iterations': 3.0,
#    'outliers_removed': 5.0},
#   'Full': {'RMSECV': 1.0264282583240156,
#    'RMSECV_MIN': 0.9223400777956894,
#    'RMSEP': 0.8115648681258109,
#    'n_spectra': '1538',
#    'outlier_removal_iterations': 8.0,
#    'outliers_removed': 48.0}},
#  'Na2O': {'High': {'RMSECV': 1.2739483442129398,
#    'RMSECV_MIN': 0.6499749247431731,
#    'RMSEP': 0.5988507690588442,
#    'n_spectra': '375',
#    'outlier_removal_iterations': 1.0,
#    'outliers_removed': 0.0},
#   'Low': {'RMSECV': 0.5738871292977707,
#    'RMSECV_MIN': 0.4814070065657079,
#    'RMSEP': 0.5660600283295928,
#    'n_spectra': '1278',
#    'outlier_removal_iterations': 3.0,
#    'outliers_removed': 8.0},
#   'Full': {'RMSECV': 1.0506884264958674,
#    'RMSECV_MIN': 0.5935789235774775,
#    'RMSEP': 0.9963165045016493,
#    'n_spectra': '1538',
#    'outlier_removal_iterations': 7.0,
#    'outliers_removed': 37.0}},
#  'CaO': {'High': {'RMSECV': 1.8938815991699092,
#    'RMSECV_MIN': 0.7214992811804952,
#    'RMSEP': 1.8528594472069229,
#    'n_spectra': '35',
#    'outlier_removal_iterations': 2.0,
#    'outliers_removed': 0.0},
#   'Mid': {'RMSECV': 1.3975832639509147,
#    'RMSECV_MIN': 1.0731657401471775,
#    'RMSEP': 1.018546691695428,
#    'n_spectra': '1428',
#    'outlier_removal_iterations': 4.0,
#    'outliers_removed': 20.0},
#   'Low': {'RMSECV': 0.7898295859444325,
#    'RMSECV_MIN': 0.5666191067192251,
#    'RMSEP': 0.7826276928974623,
#    'n_spectra': '1070',
#    'outlier_removal_iterations': 6.0,
#    'outliers_removed': 22.0},
#   'Full': {'RMSECV': 1.6205275040871123,
#    'RMSECV_MIN': 1.1900720111298186,
#    'RMSEP': 1.8128197287477454,
#    'n_spectra': '1538',
#    'outlier_removal_iterations': 8.0,
#    'outliers_removed': 41.0}},
#  'MgO': {'High': {'RMSECV': 4.416056074793203,
#    'RMSECV_MIN': 1.9934397908054573,
#    'RMSEP': 3.141065393769229,
#    'n_spectra': '135',
#    'outlier_removal_iterations': 1.0,
#    'outliers_removed': 0.0},
#   'Mid': {'RMSECV': 1.3178643801117103,
#    'RMSECV_MIN': 0.8828511701782473,
#    'RMSEP': 1.1636725121260827,
#    'n_spectra': '1488',
#    'outlier_removal_iterations': 1.0,
#    'outliers_removed': 10.0},
#   'Low': {'RMSECV': 0.49487402920592133,
#    'RMSECV_MIN': 0.44570716643172326,
#    'RMSEP': 0.6258466564490459,
#    'n_spectra': '1000',
#    'outlier_removal_iterations': 4.0,
#    'outliers_removed': 7.0},
#   'Full': {'RMSECV': 1.7393827149210086,
#    'RMSECV_MIN': 1.3590053762338363,
#    'RMSEP': 1.2518448565275888,
#    'n_spectra': '1538',
#    'outlier_removal_iterations': 6.0,
#    'outliers_removed': 41.0}},
#  'FeOT': {'High': {'RMSECV': 3.9971980853885847,
#    'RMSECV_MIN': 1.5159057166807757,
#    'RMSEP': 11.892552197111696,
#    'n_spectra': '105',
#    'outlier_removal_iterations': 2.0,
#    'outliers_removed': 0.0},
#   'Mid': {'RMSECV': 2.638608458643898,
#    'RMSECV_MIN': 2.1481430750843664,
#    'RMSEP': 1.6886432536444873,
#    'n_spectra': '978',
#    'outlier_removal_iterations': 9.0,
#    'outliers_removed': 28.0},
#   'Low': {'RMSECV': 1.811203365181979,
#    'RMSECV_MIN': 1.7157517743104516,
#    'RMSEP': 1.5478811096369867,
#    'n_spectra': '1438',
#    'outlier_removal_iterations': 3.0,
#    'outliers_removed': 1.0},
#   'Full': {'RMSECV': 2.856814504021287,
#    'RMSECV_MIN': 2.6707043162330732,
#    'RMSEP': 4.083730502154321,
#    'n_spectra': '1538',
#    'outlier_removal_iterations': 5.0,
#    'outliers_removed': 23.0}},
#  'Al2O3': {'High': {'RMSECV': 3.972923568525557,
#    'RMSECV_MIN': 1.9905950986692802,
#    'RMSEP': 2.027615260248419,
#    'n_spectra': '240',
#    'outlier_removal_iterations': 2.0,
#    'outliers_removed': 0.0},
#   'Mid': {'RMSECV': 2.2655701686817924,
#    'RMSECV_MIN': 1.5679134952493918,
#    'RMSEP': 2.040809885018913,
#    'n_spectra': '1198',
#    'outlier_removal_iterations': 2.0,
#    'outliers_removed': 12.0},
#   'Low': {'RMSECV': 2.402571210961845,
#    'RMSECV_MIN': 1.6767771327906147,
#    'RMSEP': 1.9866688757865782,
#    'n_spectra': '324',
#    'outlier_removal_iterations': 2.0,
#    'outliers_removed': 0.0},
#   'Full': {'RMSECV': 3.3052864985507995,
#    'RMSECV_MIN': 2.5907162162761357,
#    'RMSEP': 2.427277612556249,
#    'n_spectra': '1538',
#    'outlier_removal_iterations': 1.0,
#    'outliers_removed': 9.0}},
#  'TiO2': {'High': {'RMSECV': 0.7430936615694854,
#    'RMSECV_MIN': 0.11237269776607735,
#    'RMSEP': 0.09421943401141712,
#    'n_spectra': '40',
#    'outlier_removal_iterations': 2.0,
#    'outliers_removed': 0.0},
#   'Mid': {'RMSECV': 0.6245723844093781,
#    'RMSECV_MIN': 0.5695210750530553,
#    'RMSEP': 0.4391897218602988,
#    'n_spectra': '418',
#    'outlier_removal_iterations': 4.0,
#    'outliers_removed': 6.0},
#   'Low': {'RMSECV': 0.29468721878970816,
#    'RMSECV_MIN': 0.2821363118914434,
#    'RMSEP': 0.39253314186488364,
#    'n_spectra': '1359',
#    'outlier_removal_iterations': 1.0,
#    'outliers_removed': 8.0},
#   'Full': {'RMSECV': 0.4770222411554583,
#    'RMSECV_MIN': 0.3666274898015917,
#    'RMSEP': 0.4967536194007628,
#    'n_spectra': '1538',
#    'outlier_removal_iterations': 4.0,
#    'outliers_removed': 16.0}},
#  'SiO2': {'High': {'RMSECV': 3.5887213483588623,
#    'RMSECV_MIN': 3.0050303521789634,
#    'RMSEP': 4.256270641070085,
#    'n_spectra': '605',
#    'outlier_removal_iterations': 2.0,
#    'outliers_removed': 1.0},
#   'Mid': {'RMSECV': 4.712575144849369,
#    'RMSECV_MIN': 3.6385700458659307,
#    'RMSEP': 4.202617106083701,
#    'n_spectra': '1268',
#    'outlier_removal_iterations': 1.0,
#    'outliers_removed': 15.0},
#   'Low': {'RMSECV': 8.549202825187754,
#    'RMSECV_MIN': 6.143477441961021,
#    'RMSEP': 6.567753427977288,
#    'n_spectra': '439',
#    'outlier_removal_iterations': 2.0,
#    'outliers_removed': 0.0},
#   'Full': {'RMSECV': 5.983126021929221,
#    'RMSECV_MIN': 4.746931011984357,
#    'RMSEP': 7.175261306518816,
#    'n_spectra': '1538',
#    'outlier_removal_iterations': 1.0,
#    'outliers_removed': 8.0}}}

# %%
# format for latex
for oxide, submodel_data in list(results.items()).__reversed__():
    print(f"{oxide} &&&&&& \\\\")
    for submodel in submodels:
        data = submodel_data.get(submodel, None)
        if data is None:
            continue
        print(f"  {submodel} & {data['RMSECV']:.2f} & {data['RMSECV_MIN']:.2f} & {data['RMSEP']:.2f} & {data['n_spectra']} & {data['outliers_removed']:.0f} & {data['outlier_removal_iterations']:.0f} \\\\")
    print("\\\\")
# Out:
# SiO2 &&&&&& \\
#   Low & 8.55 & 6.14 & 6.57 & 439 & 0 & 2 \\
#   Mid & 4.71 & 3.64 & 4.20 & 1268 & 15 & 1 \\
#   High & 3.59 & 3.01 & 4.26 & 605 & 1 & 2 \\
#   Full & 5.98 & 4.75 & 7.18 & 1538 & 8 & 1 \\
# \\
# TiO2 &&&&&& \\
#   Low & 0.29 & 0.28 & 0.39 & 1359 & 8 & 1 \\
#   Mid & 0.62 & 0.57 & 0.44 & 418 & 6 & 4 \\
#   High & 0.74 & 0.11 & 0.09 & 40 & 0 & 2 \\
#   Full & 0.48 & 0.37 & 0.50 & 1538 & 16 & 4 \\
# \\
# Al2O3 &&&&&& \\
#   Low & 2.40 & 1.68 & 1.99 & 324 & 0 & 2 \\
#   Mid & 2.27 & 1.57 & 2.04 & 1198 & 12 & 2 \\
#   High & 3.97 & 1.99 & 2.03 & 240 & 0 & 2 \\
#   Full & 3.31 & 2.59 & 2.43 & 1538 & 9 & 1 \\
# \\
# FeOT &&&&&& \\
#   Low & 1.81 & 1.72 & 1.55 & 1438 & 1 & 3 \\
#   Mid & 2.64 & 2.15 & 1.69 & 978 & 28 & 9 \\
#   High & 4.00 & 1.52 & 11.89 & 105 & 0 & 2 \\
#   Full & 2.86 & 2.67 & 4.08 & 1538 & 23 & 5 \\
# \\
# MgO &&&&&& \\
#   Low & 0.49 & 0.45 & 0.63 & 1000 & 7 & 4 \\
#   Mid & 1.32 & 0.88 & 1.16 & 1488 & 10 & 1 \\
#   High & 4.42 & 1.99 & 3.14 & 135 & 0 & 1 \\
#   Full & 1.74 & 1.36 & 1.25 & 1538 & 41 & 6 \\
# \\
# CaO &&&&&& \\
#   Low & 0.79 & 0.57 & 0.78 & 1070 & 22 & 6 \\
#   Mid & 1.40 & 1.07 & 1.02 & 1428 & 20 & 4 \\
#   High & 1.89 & 0.72 & 1.85 & 35 & 0 & 2 \\
#   Full & 1.62 & 1.19 & 1.81 & 1538 & 41 & 8 \\
# \\
# Na2O &&&&&& \\
#   Low & 0.57 & 0.48 & 0.57 & 1278 & 8 & 3 \\
#   High & 1.27 & 0.65 & 0.60 & 375 & 0 & 1 \\
#   Full & 1.05 & 0.59 & 1.00 & 1538 & 37 & 7 \\
# \\
# K2O &&&&&& \\
#   Low & 0.39 & 0.28 & 0.34 & 773 & 5 & 3 \\
#   High & 0.98 & 0.58 & 0.71 & 920 & 13 & 2 \\
#   Full & 1.03 & 0.92 & 0.81 & 1538 & 48 & 8 \\
# \\
